# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
iris = datasets.load_iris()

# %%
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=.2, stratify=iris.target)

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
y_pred = model.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9333333333333333

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 30))
plot_tree(model, feature_names=iris.feature_names, class_names=iris.target_names)
# Out:
# [Text(334.79999999999995, 1514.3142857142857, 'petal width (cm) <= 0.8\ngini = 0.667\nsamples = 120\nvalue = [40, 40, 40]\nclass = setosa'),
#  Text(223.2, 1281.3428571428572, 'gini = 0.0\nsamples = 40\nvalue = [40, 0, 0]\nclass = setosa'),
#  Text(446.4, 1281.3428571428572, 'petal length (cm) <= 4.75\ngini = 0.5\nsamples = 80\nvalue = [0, 40, 40]\nclass = versicolor'),
#  Text(334.79999999999995, 1048.3714285714286, 'gini = 0.0\nsamples = 35\nvalue = [0, 35, 0]\nclass = versicolor'),
#  Text(558.0, 1048.3714285714286, 'petal width (cm) <= 1.75\ngini = 0.198\nsamples = 45\nvalue = [0, 5, 40]\nclass = virginica'),
#  Text(223.2, 815.4, 'sepal width (cm) <= 2.65\ngini = 0.5\nsamples = 8\nvalue = [0, 4, 4]\nclass = versicolor'),
#  Text(111.6, 582.4285714285713, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = virginica'),
#  Text(334.79999999999995, 582.4285714285713, 'petal length (cm) <= 5.05\ngini = 0.444\nsamples = 6\nvalue = [0, 4, 2]\nclass = versicolor'),
#  Text(223.2, 349.4571428571428, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]\nclass = versicolor'),
#  Text(446.4, 349.4571428571428, 'sepal length (cm) <= 6.15\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = virginica'),
#  Text(334.79999999999995, 116.48571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(558.0, 116.48571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = virginica'),
#  Text(892.8, 815.4, 'petal length (cm) <= 4.85\ngini = 0.053\nsamples = 37\nvalue = [0, 1, 36]\nclass = virginica'),
#  Text(781.1999999999999, 582.4285714285713, 'sepal length (cm) <= 5.95\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = virginica'),
#  Text(669.5999999999999, 349.4571428571428, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(892.8, 349.4571428571428, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = virginica'),
#  Text(1004.4, 582.4285714285713, 'gini = 0.0\nsamples = 34\nvalue = [0, 0, 34]\nclass = virginica')]
